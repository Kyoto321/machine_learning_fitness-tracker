# %%
import pandas as pd
from glob import glob

single_file = pd.read_csv('../../data/raw/MetaMotion/MetaMotion/A-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv')

# %%
single_file = pd.read_csv('../../data/raw/MetaMotion/MetaMotion/A-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv')

# %%
single_file = pd.read_csv('../../data/raw/MetaMotion/MetaMotion/A-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv')

# %%
single_file = pd.read_csv('../../data/raw/MetaMotion/MetaMotion/A-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv')

# %%
print(single_file)
# Out:
#         epoch (ms)             time (01:00)  elapsed (s)  x-axis (g)  \
# 0    1547219408431  2019-01-11T16:10:08.431         0.00       0.010
# 1    1547219408511  2019-01-11T16:10:08.511         0.08       0.000
# 2    1547219408591  2019-01-11T16:10:08.591         0.16       0.001
# 3    1547219408671  2019-01-11T16:10:08.671         0.24      -0.012
# 4    1547219408751  2019-01-11T16:10:08.751         0.32      -0.013
# ..             ...                      ...          ...         ...
# 201  1547219424511  2019-01-11T16:10:24.511        16.08       0.027
# 202  1547219424591  2019-01-11T16:10:24.591        16.16       0.010
# 203  1547219424671  2019-01-11T16:10:24.671        16.24       0.011
# 204  1547219424751  2019-01-11T16:10:24.751        16.32       0.008
# 205  1547219424831  2019-01-11T16:10:24.831        16.40       0.021
#
#      y-axis (g)  z-axis (g)
# 0         0.964      -0.087
# 1         0.961      -0.069
# 2         0.974      -0.087
# 3         0.971      -0.084
# 4         0.954      -0.094
# ..          ...         ...
# 201       0.970      -0.091
# 202       0.990      -0.068
# 203       0.978      -0.091
# 204       0.937      -0.085
# 205       0.966      -0.108
#
# [206 rows x 6 columns]

# %%
single_file_gyr = pd.read_csv('../../data/raw/MetaMotion/MetaMotion/A-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv')

# %%
single_file_gyr = pd.read_csv('../../data/raw/MetaMotion/MetaMotion/A-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv')

# %%
single_file_gyr = pd.read_csv('../../data/raw/MetaMotion/MetaMotion/A-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv')

# %%
print(single_file_gyr)
# Out:
#         epoch (ms)             time (01:00)  elapsed (s)  x-axis (deg/s)  \
# 0    1547219408351  2019-01-11T16:10:08.351         0.00           0.122
# 1    1547219408391  2019-01-11T16:10:08.391         0.04           2.195
# 2    1547219408431  2019-01-11T16:10:08.431         0.08           2.622
# 3    1547219408471  2019-01-11T16:10:08.471         0.12           1.951
# 4    1547219408511  2019-01-11T16:10:08.511         0.16           1.524
# ..             ...                      ...          ...             ...
# 409  1547219424711  2019-01-11T16:10:24.711        16.36           2.195
# 410  1547219424751  2019-01-11T16:10:24.751        16.40           4.451
# 411  1547219424791  2019-01-11T16:10:24.791        16.44           7.195
# 412  1547219424831  2019-01-11T16:10:24.831        16.48           8.963
# 413  1547219424871  2019-01-11T16:10:24.871        16.52          -3.476
#
#      y-axis (deg/s)  z-axis (deg/s)
# 0            -5.488          -3.841
# 1            -9.695          -0.610
# 2            -8.110          -4.024
# 3            -4.695          -4.634
# 4            -2.561          -2.500
# ..              ...             ...
# 409          -1.402           4.268
# 410          -1.220           0.244
# 411          -4.329           6.524
# 412          -1.037          -0.366
# 413           2.134          -5.305
#
# [414 rows x 6 columns]

# %%
files = glob("../../data/raw/MetaMotion/MetaMotion/*csv")

# %%
len(files)
# Out:
# 187

# %%
files[0]
# Out:
# '../../data/raw/MetaMotion/MetaMotion/C-dead-medium_MetaWear_2019-01-15T20.28.15.269_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv'

# %%
f = files[0]

# %%
f = files[0]

# %%
f
# Out:
# '../../data/raw/MetaMotion/MetaMotion/C-dead-medium_MetaWear_2019-01-15T20.28.15.269_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv'

# %%
data_path = "../../data/raw/MetaMotion/MetaMotion/"

# %%
f = files[0]

# %%
f.split("-")[0].replace(data_path, "")
# Out:
# 'C'

# %%
label = f.split("-")[1]

# %%
category = f.split("-")[2].rstrip("2")

# %%
category
# Out:
# 'medium_MetaWear_2019'

# %%
category = f.split("-")[2]

# %%
category
# Out:
# 'medium_MetaWear_2019'

# %%
category = f.split("-")[2].rstrip("2")

# %%
category = f.split("-")[2].rstrip("123")

# %%
df = pd.read_csv(f)

# %%
df
# Out:
#         epoch (ms)             time (01:00)  elapsed (s)  x-axis (g)  \
# 0    1547580495831  2019-01-15T20:28:15.831         0.00       0.036
# 1    1547580495911  2019-01-15T20:28:15.911         0.08       0.003
# 2    1547580495991  2019-01-15T20:28:15.991         0.16       0.046
# 3    1547580496071  2019-01-15T20:28:16.071         0.24       0.105
# 4    1547580496151  2019-01-15T20:28:16.151         0.32       0.012
# ..             ...                      ...          ...         ...
# 405  1547580528231  2019-01-15T20:28:48.231        32.40      -0.087
# 406  1547580528311  2019-01-15T20:28:48.311        32.48       0.179
# 407  1547580528391  2019-01-15T20:28:48.391        32.56      -0.068
# 408  1547580528471  2019-01-15T20:28:48.471        32.64      -0.066
# 409  1547580528551  2019-01-15T20:28:48.551        32.72      -0.077
#
#      y-axis (g)  z-axis (g)
# 0        -1.000      -0.270
# 1        -0.979      -0.267
# 2        -1.008      -0.276
# 3        -1.063      -0.232
# 4        -1.041      -0.276
# ..          ...         ...
# 405      -1.577      -0.278
# 406      -1.036       0.105
# 407      -0.953      -0.274
# 408      -1.063      -0.221
# 409      -0.998      -0.218
#
# [410 rows x 6 columns]

# %%
participant = f.split("-")[0].replace(data_path, "")

# %%
df["participant"] = participant

# %%
label = f.split("-")[1]

# %%
df["label"] = label

# %%
category = f.split("-")[2].rstrip("123")

# %%
df["category"] = category

# %%
df
# Out:
#         epoch (ms)             time (01:00)  elapsed (s)  x-axis (g)  \
# 0    1547580495831  2019-01-15T20:28:15.831         0.00       0.036
# 1    1547580495911  2019-01-15T20:28:15.911         0.08       0.003
# 2    1547580495991  2019-01-15T20:28:15.991         0.16       0.046
# 3    1547580496071  2019-01-15T20:28:16.071         0.24       0.105
# 4    1547580496151  2019-01-15T20:28:16.151         0.32       0.012
# ..             ...                      ...          ...         ...
# 405  1547580528231  2019-01-15T20:28:48.231        32.40      -0.087
# 406  1547580528311  2019-01-15T20:28:48.311        32.48       0.179
# 407  1547580528391  2019-01-15T20:28:48.391        32.56      -0.068
# 408  1547580528471  2019-01-15T20:28:48.471        32.64      -0.066
# 409  1547580528551  2019-01-15T20:28:48.551        32.72      -0.077
#
#      y-axis (g)  z-axis (g) participant label              category
# 0        -1.000      -0.270           C  dead  medium_MetaWear_2019
# 1        -0.979      -0.267           C  dead  medium_MetaWear_2019
# 2        -1.008      -0.276           C  dead  medium_MetaWear_2019
# 3        -1.063      -0.232           C  dead  medium_MetaWear_2019
# 4        -1.041      -0.276           C  dead  medium_MetaWear_2019
# ..          ...         ...         ...   ...                   ...
# 405      -1.577      -0.278           C  dead  medium_MetaWear_2019
# 406      -1.036       0.105           C  dead  medium_MetaWear_2019
# 407      -0.953      -0.274           C  dead  medium_MetaWear_2019
# 408      -1.063      -0.221           C  dead  medium_MetaWear_2019
# 409      -0.998      -0.218           C  dead  medium_MetaWear_2019
#
# [410 rows x 9 columns]

# %%
category = f.split("-")[2].rstrip("123").rstrip("_Metawear_2019")

# %%
category
# Out:
# 'medium_MetaW'

# %%
category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

# %%
category
# Out:
# 'medium'

# %%
accl_df = pd.DataFrame()

# %%
gyr_df = pd.DataFrame()

# %%
participant = f.split("-")[0].replace(data_path, "")

# %%
label = f.split("-")[1]

# %%
category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

# %%
print(category)
# Out:
# medium

# %%
for f in files:
    participant = f.split("-")[0].replace(data_path, "")
    label = f.split("-")[1]
    category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

# %%
for f in files:
    participant = f.split("-")[0].replace(data_path, "")
    label = f.split("-")[1]
    category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")
    print(category)
# Out:
# medium
# medium
# medium
# medium
# heavy
# heavy
# sitting
# medium
# heavy
# medium
# medium
# medium
# medium
# medium
# medium
# heavy
# heavy
# medium
# medium
# heavy
# sitting
# heavy
# medium
# heavy
# heavy
# heavy
# sitting
# medium
# heavy
# heavy
# medium
# medium
# medium
# heavy
# medium
# heavy
# medium
# heavy
# heavy
# heavy
# medium
# medium
# heavy
# standing
# medium
# medium
# heavy
# medium
# heavy
# heavy
# standing
# heavy
# heavy
# heavy
# medium
# heavy
# heavy
# sitting
# standing
# sitting
# heavy
# heavy
# heavy
# medium
# heavy
# heavy
# heavy
# medium
# medium
# medium
# heavy
# heavy
# sitting
# heavy
# medium
# heavy
# medium
# medium
# medium
# heavy
# heavy
# heavy
# heavy
# medium
# medium
# medium
# heavy
# heavy
# standing
# heavy
# medium
# heavy
# heavy
# medium
# medium
# sitting
# heavy
# heavy
# heavy
# medium
# medium
# heavy
# medium
# medium
# heavy
# heavy
# heavy
# medium
# medium
# medium
# medium
# heavy
# heavy
# sitting
# heavy
# medium
# heavy
# heavy
# medium
# heavy
# medium
# heavy
# medium
# heavy
# medium
# medium
# heavy
# medium
# medium
# medium
# medium
# heavy
# medium
# heavy
# medium
# medium
# heavy
# medium
# medium
# heavy
# heavy
# heavy
# heavy
# heavy
# standing
# heavy
# medium
# medium
# heavy
# heavy
# heavy
# standing
# medium
# medium
# standing
# medium
# medium
# heavy
# heavy
# medium
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# standing
# medium
# medium
# heavy
# heavy
# medium
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# medium
# heavy
# medium
# heavy
# heavy

# %%
if "Accelerometer" in f:
    acc_d = pd.concate([accl_df, df])

# %%
if "Gyroscope" in f:
    gyr_df - pd.concat([gyr_df, df])

# %%
gyr_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
accl_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
len(accl_df)
# Out:
# 0

# %%
for f in files:
    # extract the features
    participant = f.split("-")[0].replace(data_path, "")
    label = f.split("-")[1]
    category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")
    # read into dataframe
    df = pd.read_csv(f)
    # add columns to the dataframe
    df["participant"] = participant
    df["label"] = label
    df["category"] = category
    if "Accelerometer" in f:
        acc_d = pd.concat([accl_df, df])
    if "Gyroscope" in f:
        gyr_df - pd.concat([gyr_df, df])

# %%
len(accl_df)
# Out:
# 0

# %%
accl_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for f in files:
    # extract the features
    participant = f.split("-")[0].replace(data_path, "")
    label = f.split("-")[1]
    category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")
    # read into dataframe
    df = pd.read_csv(f)
    # add columns to the dataframe
    df["participant"] = participant
    df["label"] = label
    df["category"] = category
    if "Accelerometer" in f:
        accl_df = pd.concat([accl_df, df])
    if "Gyroscope" in f:
        gyr_df - pd.concat([gyr_df, df])

# %%
len(accl_df)
# Out:
# 23578

# %%
gyr_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
len(gyr_df)
# Out:
# 0

# %%
accl_df
# Out:
#         epoch (ms)             time (01:00)  elapsed (s)  x-axis (g)  \
# 0    1547580495831  2019-01-15T20:28:15.831         0.00       0.036
# 1    1547580495911  2019-01-15T20:28:15.911         0.08       0.003
# 2    1547580495991  2019-01-15T20:28:15.991         0.16       0.046
# 3    1547580496071  2019-01-15T20:28:16.071         0.24       0.105
# 4    1547580496151  2019-01-15T20:28:16.151         0.32       0.012
# ..             ...                      ...          ...         ...
# 215  1547221225621  2019-01-11T16:40:25.621        17.20      -0.173
# 216  1547221225701  2019-01-11T16:40:25.701        17.28      -0.164
# 217  1547221225781  2019-01-11T16:40:25.781        17.36      -0.034
# 218  1547221225861  2019-01-11T16:40:25.861        17.44      -0.095
# 219  1547221225941  2019-01-11T16:40:25.941        17.52      -0.078
#
#      y-axis (g)  z-axis (g) participant label category
# 0        -1.000      -0.270           C  dead   medium
# 1        -0.979      -0.267           C  dead   medium
# 2        -1.008      -0.276           C  dead   medium
# 3        -1.063      -0.232           C  dead   medium
# 4        -1.041      -0.276           C  dead   medium
# ..          ...         ...         ...   ...      ...
# 215       1.061      -0.206           B   ohp    heavy
# 216       1.123      -0.254           B   ohp    heavy
# 217       1.019      -0.192           B   ohp    heavy
# 218       0.942       0.015           B   ohp    heavy
# 219       1.013      -0.114           B   ohp    heavy
#
# [23578 rows x 9 columns]

# %%
gyr_df = pd.DataFrame()

# %%
for f in files:
    # extract the features
    participant = f.split("-")[0].replace(data_path, "")
    label = f.split("-")[1]
    category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")
    # read into dataframe
    df = pd.read_csv(f)
    # add columns to the dataframe
    df["participant"] = participant
    df["label"] = label
    df["category"] = category
    if "Accelerometer" in f:
        accl_df = pd.concat([accl_df, df])
    if "Gyroscope" in f:
        gyr_df - pd.concat([gyr_df, df])

len(gyr_df)
# Out:
# 0

# %%
accl_set = 1

# %%
gyr_set = 1

# %%
for f in files:
    # extract the features
    participant = f.split("-")[0].replace(data_path, "")
    label = f.split("-")[1]
    category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")
    # read into dataframe
    df = pd.read_csv(f)
    # add columns to the dataframe
    df["participant"] = participant
    df["label"] = label
    df["category"] = category
    if "Accelerometer" in f:
        accl_df = pd.concat([accl_df, df])
    if "Gyroscope" in f:
        gyr_df - pd.concat([gyr_df, df])

len(gyr_df)
# Out:
# 0

# %%
gyr_df = pd.concat([gyr_df, df])

# %%
for f in files:
    # extract the features
    participant = f.split("-")[0].replace(data_path, "")
    label = f.split("-")[1]
    category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")
    # read into dataframe
    df = pd.read_csv(f)
    # add columns to the dataframe
    df["participant"] = participant
    df["label"] = label
    df["category"] = category
    if "Accelerometer" in f:
        accl_df = pd.concat([accl_df, df])
    if "Gyroscope" in f:
        gyr_df = pd.concat([gyr_df, df])

len(gyr_df)
# Out:
# 47436

# %%
gyr_df = pd.concat([gyr_df, df])

# %%
for f in files:
    # extract the features
    participant = f.split("-")[0].replace(data_path, "")
    label = f.split("-")[1]
    category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")
    # read into dataframe
    df = pd.read_csv(f)
    # add columns to the dataframe
    df["participant"] = participant
    df["label"] = label
    df["category"] = category
    if "Accelerometer" in f:
        df["set"] = accl_set
        accl_df = pd.concat([accl_df, df])
    if "Gyroscope" in f:
        df["set"] = gyr_set
        gyr_df = pd.concat([gyr_df, df])

# %%
f
# Out:
# '../../data/raw/MetaMotion/MetaMotion/A-row-heavy_MetaWear_2019-01-14T15.04.06.123_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv'

# %%
gyr_df
# Out:
#         epoch (ms)             time (01:00)  elapsed (s)  x-axis (deg/s)  \
# 0    1547474646331  2019-01-14T15:04:06.331         0.00           1.402
# 1    1547474646371  2019-01-14T15:04:06.371         0.04           1.341
# 2    1547474646411  2019-01-14T15:04:06.411         0.08          -1.280
# 3    1547474646451  2019-01-14T15:04:06.451         0.12          -1.829
# 4    1547474646491  2019-01-14T15:04:06.491         0.16          -1.951
# ..             ...                      ...          ...             ...
# 213  1547474654851  2019-01-14T15:04:14.851         8.52           2.317
# 214  1547474654891  2019-01-14T15:04:14.891         8.56           2.622
# 215  1547474654931  2019-01-14T15:04:14.931         8.60           0.305
# 216  1547474654971  2019-01-14T15:04:14.971         8.64          -0.671
# 217  1547474655011  2019-01-14T15:04:15.011         8.68          -0.610
#
#      y-axis (deg/s)  z-axis (deg/s) participant label category  set
# 0            -6.280           1.585           A   row    heavy  NaN
# 1            -5.427           0.915           A   row    heavy  NaN
# 2             0.671          -1.829           A   row    heavy  NaN
# 3             0.366          -0.549           A   row    heavy  NaN
# 4            -2.683           1.829           A   row    heavy  NaN
# ..              ...             ...         ...   ...      ...  ...
# 213          -1.524          -2.378           A   row    heavy  1.0
# 214          -7.561           2.073           A   row    heavy  1.0
# 215          -2.744           2.500           A   row    heavy  1.0
# 216          -3.293          -0.061           A   row    heavy  1.0
# 217          -0.427           1.159           A   row    heavy  1.0
#
# [95528 rows x 10 columns]

# %%
accl_df
# Out:
#         epoch (ms)             time (01:00)  elapsed (s)  x-axis (g)  \
# 0    1547580495831  2019-01-15T20:28:15.831         0.00       0.036
# 1    1547580495911  2019-01-15T20:28:15.911         0.08       0.003
# 2    1547580495991  2019-01-15T20:28:15.991         0.16       0.046
# 3    1547580496071  2019-01-15T20:28:16.071         0.24       0.105
# 4    1547580496151  2019-01-15T20:28:16.151         0.32       0.012
# ..             ...                      ...          ...         ...
# 215  1547221225621  2019-01-11T16:40:25.621        17.20      -0.173
# 216  1547221225701  2019-01-11T16:40:25.701        17.28      -0.164
# 217  1547221225781  2019-01-11T16:40:25.781        17.36      -0.034
# 218  1547221225861  2019-01-11T16:40:25.861        17.44      -0.095
# 219  1547221225941  2019-01-11T16:40:25.941        17.52      -0.078
#
#      y-axis (g)  z-axis (g) participant label category  set
# 0        -1.000      -0.270           C  dead   medium  NaN
# 1        -0.979      -0.267           C  dead   medium  NaN
# 2        -1.008      -0.276           C  dead   medium  NaN
# 3        -1.063      -0.232           C  dead   medium  NaN
# 4        -1.041      -0.276           C  dead   medium  NaN
# ..          ...         ...         ...   ...      ...  ...
# 215       1.061      -0.206           B   ohp    heavy  1.0
# 216       1.123      -0.254           B   ohp    heavy  1.0
# 217       1.019      -0.192           B   ohp    heavy  1.0
# 218       0.942       0.015           B   ohp    heavy  1.0
# 219       1.013      -0.114           B   ohp    heavy  1.0
#
# [118474 rows x 10 columns]

# %%
for f in files:
    # extract the features
    participant = f.split("-")[0].replace(data_path, "")
    label = f.split("-")[1]
    category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")
    # read into dataframe
    df = pd.read_csv(f)
    # add columns to the dataframe
    df["participant"] = participant
    df["label"] = label
    df["category"] = category
    if "Accelerometer" in f:
        df["set"] = accl_set # remove NaN for set values
        accl_set += 1
        accl_df = pd.concat([accl_df, df])
    if "Gyroscope" in f:
        df["set"] = gyr_set # remove NaN for set values
        gyr_set += 1
        gyr_df = pd.concat([gyr_df, df])

# %%
accl_df
# Out:
#         epoch (ms)             time (01:00)  elapsed (s)  x-axis (g)  \
# 0    1547580495831  2019-01-15T20:28:15.831         0.00       0.036
# 1    1547580495911  2019-01-15T20:28:15.911         0.08       0.003
# 2    1547580495991  2019-01-15T20:28:15.991         0.16       0.046
# 3    1547580496071  2019-01-15T20:28:16.071         0.24       0.105
# 4    1547580496151  2019-01-15T20:28:16.151         0.32       0.012
# ..             ...                      ...          ...         ...
# 215  1547221225621  2019-01-11T16:40:25.621        17.20      -0.173
# 216  1547221225701  2019-01-11T16:40:25.701        17.28      -0.164
# 217  1547221225781  2019-01-11T16:40:25.781        17.36      -0.034
# 218  1547221225861  2019-01-11T16:40:25.861        17.44      -0.095
# 219  1547221225941  2019-01-11T16:40:25.941        17.52      -0.078
#
#      y-axis (g)  z-axis (g) participant label category   set
# 0        -1.000      -0.270           C  dead   medium   NaN
# 1        -0.979      -0.267           C  dead   medium   NaN
# 2        -1.008      -0.276           C  dead   medium   NaN
# 3        -1.063      -0.232           C  dead   medium   NaN
# 4        -1.041      -0.276           C  dead   medium   NaN
# ..          ...         ...         ...   ...      ...   ...
# 215       1.061      -0.206           B   ohp    heavy  94.0
# 216       1.123      -0.254           B   ohp    heavy  94.0
# 217       1.019      -0.192           B   ohp    heavy  94.0
# 218       0.942       0.015           B   ohp    heavy  94.0
# 219       1.013      -0.114           B   ohp    heavy  94.0
#
# [142052 rows x 10 columns]

# %%
data_path = "../../data/raw/MetaMotion/MetaMotion/"

# %%
f = files[0]

# %%
participant = f.split("-")[0].replace(data_path, "")

# %%
label = f.split("-")[1]

# %%
category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

# %%
df = pd.read_csv(f)

# %%
df["participant"] = participant

# %%
df["label"] = label

# %%
df["category"] = category

# %%
accl_df = pd.DataFrame()

# %%
gyr_df = pd.DataFrame()

# %%
accl_set = 1

# %%
gyr_set = 1

# %%
for f in files:
    # extract the features
    participant = f.split("-")[0].replace(data_path, "")
    label = f.split("-")[1]
    category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")
    # read into dataframe
    df = pd.read_csv(f)
    # add columns to the dataframe
    df["participant"] = participant
    df["label"] = label
    df["category"] = category
    if "Accelerometer" in f:
        df["set"] = accl_set # remove NaN for set values
        accl_set += 1
        accl_df = pd.concat([accl_df, df])
    if "Gyroscope" in f:
        df["set"] = gyr_set # remove NaN for set values
        gyr_set += 1
        gyr_df = pd.concat([gyr_df, df])

# %%
len(gyr_df)
# Out:
# 47218

# %%
gyr_df
# Out:
#         epoch (ms)             time (01:00)  elapsed (s)  x-axis (deg/s)  \
# 0    1547667034809  2019-01-16 20:30:34.809         0.00           4.207
# 1    1547667034849  2019-01-16 20:30:34.849         0.04           3.659
# 2    1547667034889  2019-01-16 20:30:34.889         0.08           3.415
# 3    1547667034929  2019-01-16 20:30:34.929         0.12           5.488
# 4    1547667034969  2019-01-16 20:30:34.969         0.16           7.012
# ..             ...                      ...          ...             ...
# 213  1547474654851  2019-01-14T15:04:14.851         8.52           2.317
# 214  1547474654891  2019-01-14T15:04:14.891         8.56           2.622
# 215  1547474654931  2019-01-14T15:04:14.931         8.60           0.305
# 216  1547474654971  2019-01-14T15:04:14.971         8.64          -0.671
# 217  1547474655011  2019-01-14T15:04:15.011         8.68          -0.610
#
#      y-axis (deg/s)  z-axis (deg/s) participant label category  set
# 0            -2.012          -0.305           E  dead   medium    1
# 1            -2.317           0.305           E  dead   medium    1
# 2            -1.890           1.341           E  dead   medium    1
# 3            -3.415           2.988           E  dead   medium    1
# 4            -7.927           3.049           E  dead   medium    1
# ..              ...             ...         ...   ...      ...  ...
# 213          -1.524          -2.378           A   row    heavy   93
# 214          -7.561           2.073           A   row    heavy   93
# 215          -2.744           2.500           A   row    heavy   93
# 216          -3.293          -0.061           A   row    heavy   93
# 217          -0.427           1.159           A   row    heavy   93
#
# [47218 rows x 10 columns]

# %%
pd.to_datetime(accl_df["epoch (ms)"], unit="ms")
# Out:
# 0     2019-01-15 19:28:15.831
# 1     2019-01-15 19:28:15.911
# 2     2019-01-15 19:28:15.991
# 3     2019-01-15 19:28:16.071
# 4     2019-01-15 19:28:16.151
#                 ...
# 215   2019-01-11 15:40:25.621
# 216   2019-01-11 15:40:25.701
# 217   2019-01-11 15:40:25.781
# 218   2019-01-11 15:40:25.861
# 219   2019-01-11 15:40:25.941
# Name: epoch (ms), Length: 23578, dtype: datetime64[ns]

# %%
accl_df.index = pd.to_datetime(accl_df["epoch (ms)"], unit="ms")

# %%
gyr_df.index = pd.to_datetime(gyr_df["epoch (ms)"], unit="ms")

# %%
del accl_df["epoch (ms)"]
del accl_df["time (01:00)"]
del accl_df["elapsed (s)"]
del gyr_df["epoch (ms)"]
del gyr_df["time (01:00)"]
del gyr_df["elapsed (s)"]

# %%
accl_df
# Out:
#                          x-axis (g)  y-axis (g)  z-axis (g) participant label  \
# epoch (ms)
# 2019-01-15 19:28:15.831       0.036      -1.000      -0.270           C  dead
# 2019-01-15 19:28:15.911       0.003      -0.979      -0.267           C  dead
# 2019-01-15 19:28:15.991       0.046      -1.008      -0.276           C  dead
# 2019-01-15 19:28:16.071       0.105      -1.063      -0.232           C  dead
# 2019-01-15 19:28:16.151       0.012      -1.041      -0.276           C  dead
# ...                             ...         ...         ...         ...   ...
# 2019-01-11 15:40:25.621      -0.173       1.061      -0.206           B   ohp
# 2019-01-11 15:40:25.701      -0.164       1.123      -0.254           B   ohp
# 2019-01-11 15:40:25.781      -0.034       1.019      -0.192           B   ohp
# 2019-01-11 15:40:25.861      -0.095       0.942       0.015           B   ohp
# 2019-01-11 15:40:25.941      -0.078       1.013      -0.114           B   ohp
#
#                         category  set
# epoch (ms)
# 2019-01-15 19:28:15.831   medium    1
# 2019-01-15 19:28:15.911   medium    1
# 2019-01-15 19:28:15.991   medium    1
# 2019-01-15 19:28:16.071   medium    1
# 2019-01-15 19:28:16.151   medium    1
# ...                          ...  ...
# 2019-01-11 15:40:25.621    heavy   94
# 2019-01-11 15:40:25.701    heavy   94
# 2019-01-11 15:40:25.781    heavy   94
# 2019-01-11 15:40:25.861    heavy   94
# 2019-01-11 15:40:25.941    heavy   94
#
# [23578 rows x 7 columns]

# %%
def read_data_from_files(files):
    # read all files
    accl_df = pd.DataFrame()
    gyr_df = pd.DataFrame()
    # to create unique identifier
    accl_set = 1
    gyr_set = 1
    for f in files:
        # extract the features
        participant = f.split("-")[0].replace(data_path, "")
        label = f.split("-")[1]
        category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")
        # read into dataframe
        df = pd.read_csv(f)
        # add columns to the dataframe
        df["participant"] = participant
        df["label"] = label
        df["category"] = category
        if "Accelerometer" in f:
            df["set"] = accl_set # remove NaN for set values
            accl_set += 1
            accl_df = pd.concat([accl_df, df])
        if "Gyroscope" in f:
            df["set"] = gyr_set # remove NaN for set values
            gyr_set += 1
            gyr_df = pd.concat([gyr_df, df])
    accl_df.index = pd.to_datetime(accl_df["epoch (ms)"], unit="ms")
    gyr_df.index = pd.to_datetime(gyr_df["epoch (ms)"], unit="ms")
    # remove column
    del accl_df["epoch (ms)"]
    del accl_df["time (01:00)"]
    del accl_df["elapsed (s)"]
    del gyr_df["epoch (ms)"]
    del gyr_df["time (01:00)"]
    del gyr_df["elapsed (s)"]        
    return accl_df, gyr_df

# %%
accl_df, gyr_df = read_data_from_files(files)

# %%
accl_df, gyr_df = read_data_from_files(files)

# %%
gyr_df
# Out:
#                          x-axis (deg/s)  y-axis (deg/s)  z-axis (deg/s)  \
# epoch (ms)
# 2019-01-16 19:30:34.809           4.207          -2.012          -0.305
# 2019-01-16 19:30:34.849           3.659          -2.317           0.305
# 2019-01-16 19:30:34.889           3.415          -1.890           1.341
# 2019-01-16 19:30:34.929           5.488          -3.415           2.988
# 2019-01-16 19:30:34.969           7.012          -7.927           3.049
# ...                                 ...             ...             ...
# 2019-01-14 14:04:14.851           2.317          -1.524          -2.378
# 2019-01-14 14:04:14.891           2.622          -7.561           2.073
# 2019-01-14 14:04:14.931           0.305          -2.744           2.500
# 2019-01-14 14:04:14.971          -0.671          -3.293          -0.061
# 2019-01-14 14:04:15.011          -0.610          -0.427           1.159
#
#                         participant label category  set
# epoch (ms)
# 2019-01-16 19:30:34.809           E  dead   medium    1
# 2019-01-16 19:30:34.849           E  dead   medium    1
# 2019-01-16 19:30:34.889           E  dead   medium    1
# 2019-01-16 19:30:34.929           E  dead   medium    1
# 2019-01-16 19:30:34.969           E  dead   medium    1
# ...                             ...   ...      ...  ...
# 2019-01-14 14:04:14.851           A   row    heavy   93
# 2019-01-14 14:04:14.891           A   row    heavy   93
# 2019-01-14 14:04:14.931           A   row    heavy   93
# 2019-01-14 14:04:14.971           A   row    heavy   93
# 2019-01-14 14:04:15.011           A   row    heavy   93
#
# [47218 rows x 7 columns]

# %%
accl_d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Desktop/works/ml_fitness_tracker/src/data/dataset.py in <module>
# ----> <a href='file:///home/kyoto_123/Desktop/works/ml_fitness_tracker/src/data/dataset.py?line=132'>133</a> accl_d
#
# NameError: name 'accl_d' is not defined

# %%
accl_df
# Out:
#                          x-axis (g)  y-axis (g)  z-axis (g) participant label  \
# epoch (ms)
# 2019-01-15 19:28:15.831       0.036      -1.000      -0.270           C  dead
# 2019-01-15 19:28:15.911       0.003      -0.979      -0.267           C  dead
# 2019-01-15 19:28:15.991       0.046      -1.008      -0.276           C  dead
# 2019-01-15 19:28:16.071       0.105      -1.063      -0.232           C  dead
# 2019-01-15 19:28:16.151       0.012      -1.041      -0.276           C  dead
# ...                             ...         ...         ...         ...   ...
# 2019-01-11 15:40:25.621      -0.173       1.061      -0.206           B   ohp
# 2019-01-11 15:40:25.701      -0.164       1.123      -0.254           B   ohp
# 2019-01-11 15:40:25.781      -0.034       1.019      -0.192           B   ohp
# 2019-01-11 15:40:25.861      -0.095       0.942       0.015           B   ohp
# 2019-01-11 15:40:25.941      -0.078       1.013      -0.114           B   ohp
#
#                         category  set
# epoch (ms)
# 2019-01-15 19:28:15.831   medium    1
# 2019-01-15 19:28:15.911   medium    1
# 2019-01-15 19:28:15.991   medium    1
# 2019-01-15 19:28:16.071   medium    1
# 2019-01-15 19:28:16.151   medium    1
# ...                          ...  ...
# 2019-01-11 15:40:25.621    heavy   94
# 2019-01-11 15:40:25.701    heavy   94
# 2019-01-11 15:40:25.781    heavy   94
# 2019-01-11 15:40:25.861    heavy   94
# 2019-01-11 15:40:25.941    heavy   94
#
# [23578 rows x 7 columns]

# %%
pd.concat([accl_df.iloc[:,:3], gyr_df], axis=1)
# Out:
#                          x-axis (g)  y-axis (g)  z-axis (g)  x-axis (deg/s)  \
# epoch (ms)
# 2019-01-11 15:08:04.950         NaN         NaN         NaN         -10.671
# 2019-01-11 15:08:04.990         NaN         NaN         NaN          -8.720
# 2019-01-11 15:08:05.030         NaN         NaN         NaN           0.488
# 2019-01-11 15:08:05.070         NaN         NaN         NaN           0.244
# 2019-01-11 15:08:05.110         NaN         NaN         NaN          -0.915
# ...                             ...         ...         ...             ...
# 2019-01-20 17:35:13.382      -0.060      -1.021      -0.058             NaN
# 2019-01-20 17:35:13.462      -0.035      -1.037      -0.026             NaN
# 2019-01-20 17:35:13.542      -0.045      -1.029      -0.033             NaN
# 2019-01-20 17:35:13.622      -0.039      -1.027      -0.039             NaN
# 2019-01-20 17:35:13.702      -0.049      -1.031      -0.049             NaN
#
#                          y-axis (deg/s)  z-axis (deg/s) participant  label  \
# epoch (ms)
# 2019-01-11 15:08:04.950          -1.524           5.976           B  bench
# 2019-01-11 15:08:04.990          -2.073           3.171           B  bench
# 2019-01-11 15:08:05.030          -3.537          -4.146           B  bench
# 2019-01-11 15:08:05.070          -5.854           3.537           B  bench
# 2019-01-11 15:08:05.110           0.061          -2.805           B  bench
# ...                                 ...             ...         ...    ...
# 2019-01-20 17:35:13.382             NaN             NaN         NaN    NaN
# 2019-01-20 17:35:13.462             NaN             NaN         NaN    NaN
# 2019-01-20 17:35:13.542             NaN             NaN         NaN    NaN
# 2019-01-20 17:35:13.622             NaN             NaN         NaN    NaN
# 2019-01-20 17:35:13.702             NaN             NaN         NaN    NaN
#
#                         category   set
# epoch (ms)
# 2019-01-11 15:08:04.950    heavy  80.0
# 2019-01-11 15:08:04.990    heavy  80.0
# 2019-01-11 15:08:05.030    heavy  80.0
# 2019-01-11 15:08:05.070    heavy  80.0
# 2019-01-11 15:08:05.110    heavy  80.0
# ...                          ...   ...
# 2019-01-20 17:35:13.382      NaN   NaN
# 2019-01-20 17:35:13.462      NaN   NaN
# 2019-01-20 17:35:13.542      NaN   NaN
# 2019-01-20 17:35:13.622      NaN   NaN
# 2019-01-20 17:35:13.702      NaN   NaN
#
# [69677 rows x 10 columns]

# %%
pd.concat([accl_df.iloc[:,:3], gyr_df], axis=1)
# Out:
#                          x-axis (g)  y-axis (g)  z-axis (g)  x-axis (deg/s)  \
# epoch (ms)
# 2019-01-11 15:08:04.950         NaN         NaN         NaN         -10.671
# 2019-01-11 15:08:04.990         NaN         NaN         NaN          -8.720
# 2019-01-11 15:08:05.030         NaN         NaN         NaN           0.488
# 2019-01-11 15:08:05.070         NaN         NaN         NaN           0.244
# 2019-01-11 15:08:05.110         NaN         NaN         NaN          -0.915
# ...                             ...         ...         ...             ...
# 2019-01-20 17:35:13.382      -0.060      -1.021      -0.058             NaN
# 2019-01-20 17:35:13.462      -0.035      -1.037      -0.026             NaN
# 2019-01-20 17:35:13.542      -0.045      -1.029      -0.033             NaN
# 2019-01-20 17:35:13.622      -0.039      -1.027      -0.039             NaN
# 2019-01-20 17:35:13.702      -0.049      -1.031      -0.049             NaN
#
#                          y-axis (deg/s)  z-axis (deg/s) participant  label  \
# epoch (ms)
# 2019-01-11 15:08:04.950          -1.524           5.976           B  bench
# 2019-01-11 15:08:04.990          -2.073           3.171           B  bench
# 2019-01-11 15:08:05.030          -3.537          -4.146           B  bench
# 2019-01-11 15:08:05.070          -5.854           3.537           B  bench
# 2019-01-11 15:08:05.110           0.061          -2.805           B  bench
# ...                                 ...             ...         ...    ...
# 2019-01-20 17:35:13.382             NaN             NaN         NaN    NaN
# 2019-01-20 17:35:13.462             NaN             NaN         NaN    NaN
# 2019-01-20 17:35:13.542             NaN             NaN         NaN    NaN
# 2019-01-20 17:35:13.622             NaN             NaN         NaN    NaN
# 2019-01-20 17:35:13.702             NaN             NaN         NaN    NaN
#
#                         category   set
# epoch (ms)
# 2019-01-11 15:08:04.950    heavy  80.0
# 2019-01-11 15:08:04.990    heavy  80.0
# 2019-01-11 15:08:05.030    heavy  80.0
# 2019-01-11 15:08:05.070    heavy  80.0
# 2019-01-11 15:08:05.110    heavy  80.0
# ...                          ...   ...
# 2019-01-20 17:35:13.382      NaN   NaN
# 2019-01-20 17:35:13.462      NaN   NaN
# 2019-01-20 17:35:13.542      NaN   NaN
# 2019-01-20 17:35:13.622      NaN   NaN
# 2019-01-20 17:35:13.702      NaN   NaN
#
# [69677 rows x 10 columns]

# %%
pd.concat([accl_df.iloc[:3], gyr_df], axis=1)
# Out:
#                          x-axis (g)  y-axis (g)  z-axis (g) participant label  \
# epoch (ms)
# 2019-01-11 15:08:04.950         NaN         NaN         NaN         NaN   NaN
# 2019-01-11 15:08:04.990         NaN         NaN         NaN         NaN   NaN
# 2019-01-11 15:08:05.030         NaN         NaN         NaN         NaN   NaN
# 2019-01-11 15:08:05.070         NaN         NaN         NaN         NaN   NaN
# 2019-01-11 15:08:05.110         NaN         NaN         NaN         NaN   NaN
# ...                             ...         ...         ...         ...   ...
# 2019-01-20 17:33:27.647         NaN         NaN         NaN         NaN   NaN
# 2019-01-20 17:33:27.687         NaN         NaN         NaN         NaN   NaN
# 2019-01-20 17:33:27.727         NaN         NaN         NaN         NaN   NaN
# 2019-01-20 17:33:27.767         NaN         NaN         NaN         NaN   NaN
# 2019-01-20 17:33:27.807         NaN         NaN         NaN         NaN   NaN
#
#                         category  set  x-axis (deg/s)  y-axis (deg/s)  \
# epoch (ms)
# 2019-01-11 15:08:04.950      NaN  NaN         -10.671          -1.524
# 2019-01-11 15:08:04.990      NaN  NaN          -8.720          -2.073
# 2019-01-11 15:08:05.030      NaN  NaN           0.488          -3.537
# 2019-01-11 15:08:05.070      NaN  NaN           0.244          -5.854
# 2019-01-11 15:08:05.110      NaN  NaN          -0.915           0.061
# ...                          ...  ...             ...             ...
# 2019-01-20 17:33:27.647      NaN  NaN           3.537          -5.061
# 2019-01-20 17:33:27.687      NaN  NaN          -0.305          -1.829
# 2019-01-20 17:33:27.727      NaN  NaN          -0.488           3.659
# 2019-01-20 17:33:27.767      NaN  NaN          -0.915          -0.427
# 2019-01-20 17:33:27.807      NaN  NaN           1.098          -4.024
#
#                          z-axis (deg/s) participant  label category   set
# epoch (ms)
# 2019-01-11 15:08:04.950           5.976           B  bench    heavy  80.0
# 2019-01-11 15:08:04.990           3.171           B  bench    heavy  80.0
# 2019-01-11 15:08:05.030          -4.146           B  bench    heavy  80.0
# 2019-01-11 15:08:05.070           3.537           B  bench    heavy  80.0
# 2019-01-11 15:08:05.110          -2.805           B  bench    heavy  80.0
# ...                                 ...         ...    ...      ...   ...
# 2019-01-20 17:33:27.647           2.683           E    row   medium  92.0
# 2019-01-20 17:33:27.687           1.402           E    row   medium  92.0
# 2019-01-20 17:33:27.727          -2.195           E    row   medium  92.0
# 2019-01-20 17:33:27.767           1.159           E    row   medium  92.0
# 2019-01-20 17:33:27.807           0.976           E    row   medium  92.0
#
# [47221 rows x 14 columns]

# %%
accl_df, gyr_df = read_data_from_files(files)

# %%
accl_df
# Out:
#                          x-axis (g)  y-axis (g)  z-axis (g) participant label  \
# epoch (ms)
# 2019-01-15 19:28:15.831       0.036      -1.000      -0.270           C  dead
# 2019-01-15 19:28:15.911       0.003      -0.979      -0.267           C  dead
# 2019-01-15 19:28:15.991       0.046      -1.008      -0.276           C  dead
# 2019-01-15 19:28:16.071       0.105      -1.063      -0.232           C  dead
# 2019-01-15 19:28:16.151       0.012      -1.041      -0.276           C  dead
# ...                             ...         ...         ...         ...   ...
# 2019-01-11 15:40:25.621      -0.173       1.061      -0.206           B   ohp
# 2019-01-11 15:40:25.701      -0.164       1.123      -0.254           B   ohp
# 2019-01-11 15:40:25.781      -0.034       1.019      -0.192           B   ohp
# 2019-01-11 15:40:25.861      -0.095       0.942       0.015           B   ohp
# 2019-01-11 15:40:25.941      -0.078       1.013      -0.114           B   ohp
#
#                         category  set
# epoch (ms)
# 2019-01-15 19:28:15.831   medium    1
# 2019-01-15 19:28:15.911   medium    1
# 2019-01-15 19:28:15.991   medium    1
# 2019-01-15 19:28:16.071   medium    1
# 2019-01-15 19:28:16.151   medium    1
# ...                          ...  ...
# 2019-01-11 15:40:25.621    heavy   94
# 2019-01-11 15:40:25.701    heavy   94
# 2019-01-11 15:40:25.781    heavy   94
# 2019-01-11 15:40:25.861    heavy   94
# 2019-01-11 15:40:25.941    heavy   94
#
# [23578 rows x 7 columns]

# %%
gyr_df
# Out:
#                          x-axis (deg/s)  y-axis (deg/s)  z-axis (deg/s)  \
# epoch (ms)
# 2019-01-16 19:30:34.809           4.207          -2.012          -0.305
# 2019-01-16 19:30:34.849           3.659          -2.317           0.305
# 2019-01-16 19:30:34.889           3.415          -1.890           1.341
# 2019-01-16 19:30:34.929           5.488          -3.415           2.988
# 2019-01-16 19:30:34.969           7.012          -7.927           3.049
# ...                                 ...             ...             ...
# 2019-01-14 14:04:14.851           2.317          -1.524          -2.378
# 2019-01-14 14:04:14.891           2.622          -7.561           2.073
# 2019-01-14 14:04:14.931           0.305          -2.744           2.500
# 2019-01-14 14:04:14.971          -0.671          -3.293          -0.061
# 2019-01-14 14:04:15.011          -0.610          -0.427           1.159
#
#                         participant label category  set
# epoch (ms)
# 2019-01-16 19:30:34.809           E  dead   medium    1
# 2019-01-16 19:30:34.849           E  dead   medium    1
# 2019-01-16 19:30:34.889           E  dead   medium    1
# 2019-01-16 19:30:34.929           E  dead   medium    1
# 2019-01-16 19:30:34.969           E  dead   medium    1
# ...                             ...   ...      ...  ...
# 2019-01-14 14:04:14.851           A   row    heavy   93
# 2019-01-14 14:04:14.891           A   row    heavy   93
# 2019-01-14 14:04:14.931           A   row    heavy   93
# 2019-01-14 14:04:14.971           A   row    heavy   93
# 2019-01-14 14:04:15.011           A   row    heavy   93
#
# [47218 rows x 7 columns]

# %%
pd.concat([accl_df.iloc[:,:3], gyr_df], axis=1)
# Out:
#                          x-axis (g)  y-axis (g)  z-axis (g)  x-axis (deg/s)  \
# epoch (ms)
# 2019-01-11 15:08:04.950         NaN         NaN         NaN         -10.671
# 2019-01-11 15:08:04.990         NaN         NaN         NaN          -8.720
# 2019-01-11 15:08:05.030         NaN         NaN         NaN           0.488
# 2019-01-11 15:08:05.070         NaN         NaN         NaN           0.244
# 2019-01-11 15:08:05.110         NaN         NaN         NaN          -0.915
# ...                             ...         ...         ...             ...
# 2019-01-20 17:35:13.382      -0.060      -1.021      -0.058             NaN
# 2019-01-20 17:35:13.462      -0.035      -1.037      -0.026             NaN
# 2019-01-20 17:35:13.542      -0.045      -1.029      -0.033             NaN
# 2019-01-20 17:35:13.622      -0.039      -1.027      -0.039             NaN
# 2019-01-20 17:35:13.702      -0.049      -1.031      -0.049             NaN
#
#                          y-axis (deg/s)  z-axis (deg/s) participant  label  \
# epoch (ms)
# 2019-01-11 15:08:04.950          -1.524           5.976           B  bench
# 2019-01-11 15:08:04.990          -2.073           3.171           B  bench
# 2019-01-11 15:08:05.030          -3.537          -4.146           B  bench
# 2019-01-11 15:08:05.070          -5.854           3.537           B  bench
# 2019-01-11 15:08:05.110           0.061          -2.805           B  bench
# ...                                 ...             ...         ...    ...
# 2019-01-20 17:35:13.382             NaN             NaN         NaN    NaN
# 2019-01-20 17:35:13.462             NaN             NaN         NaN    NaN
# 2019-01-20 17:35:13.542             NaN             NaN         NaN    NaN
# 2019-01-20 17:35:13.622             NaN             NaN         NaN    NaN
# 2019-01-20 17:35:13.702             NaN             NaN         NaN    NaN
#
#                         category   set
# epoch (ms)
# 2019-01-11 15:08:04.950    heavy  80.0
# 2019-01-11 15:08:04.990    heavy  80.0
# 2019-01-11 15:08:05.030    heavy  80.0
# 2019-01-11 15:08:05.070    heavy  80.0
# 2019-01-11 15:08:05.110    heavy  80.0
# ...                          ...   ...
# 2019-01-20 17:35:13.382      NaN   NaN
# 2019-01-20 17:35:13.462      NaN   NaN
# 2019-01-20 17:35:13.542      NaN   NaN
# 2019-01-20 17:35:13.622      NaN   NaN
# 2019-01-20 17:35:13.702      NaN   NaN
#
# [69677 rows x 10 columns]

# %%
merged_data = pd.concat([accl_df.iloc[:,:3], gyr_df], axis=1)

# %%
merged_data.dropna()
# Out:
#                          x-axis (g)  y-axis (g)  z-axis (g)  x-axis (deg/s)  \
# epoch (ms)
# 2019-01-11 15:10:08.431       0.010       0.964      -0.087           2.622
# 2019-01-11 15:10:08.511       0.000       0.961      -0.069           1.524
# 2019-01-11 15:10:08.591       0.001       0.974      -0.087           1.707
# 2019-01-11 15:10:08.671      -0.012       0.971      -0.084           2.683
# 2019-01-11 15:10:08.751      -0.013       0.954      -0.094           1.524
# ...                             ...         ...         ...             ...
# 2019-01-15 19:04:25.561       0.369       0.591       0.761          11.220
# 2019-01-15 19:04:25.641       0.387       0.566       0.776           3.963
# 2019-01-15 19:04:25.721       0.361       0.574       0.680          15.305
# 2019-01-15 19:04:25.801       0.353       0.583       0.635          30.366
# 2019-01-15 19:04:25.881       0.359       0.605       0.678          14.756
#
#                          y-axis (deg/s)  z-axis (deg/s) participant  label  \
# epoch (ms)
# 2019-01-11 15:10:08.431          -8.110          -4.024           A  bench
# 2019-01-11 15:10:08.511          -2.561          -2.500           A  bench
# 2019-01-11 15:10:08.591          -5.366           0.915           A  bench
# 2019-01-11 15:10:08.671          -4.146          -1.220           A  bench
# 2019-01-11 15:10:08.751           0.610          -3.171           A  bench
# ...                                 ...             ...         ...    ...
# 2019-01-15 19:04:25.561          -5.061          -5.061           A  squat
# 2019-01-15 19:04:25.641          -2.988          -0.793           A  squat
# 2019-01-15 19:04:25.721          -3.293          -0.671           A  squat
# 2019-01-15 19:04:25.801          -0.122          -4.573           A  squat
# 2019-01-15 19:04:25.881          -6.585          -2.378           A  squat
#
#                         category   set
# epoch (ms)
# 2019-01-11 15:10:08.431    heavy  47.0
# 2019-01-11 15:10:08.511    heavy  47.0
# 2019-01-11 15:10:08.591    heavy  47.0
# 2019-01-11 15:10:08.671    heavy  47.0
# 2019-01-11 15:10:08.751    heavy  47.0
# ...                          ...   ...
# 2019-01-15 19:04:25.561    heavy  56.0
# 2019-01-15 19:04:25.641    heavy  56.0
# 2019-01-15 19:04:25.721    heavy  56.0
# 2019-01-15 19:04:25.801    heavy  56.0
# 2019-01-15 19:04:25.881    heavy  56.0
#
# [1119 rows x 10 columns]

# %%
"set"
# Out:
# 'set'

# %%
merged_data.columns = ["accl_x", "accl_y", "accl_z", "gyr_x", "gyr_y", "gyr_z", "label", "category", "participant", "set",]

# %%
merged_data.columns
# Out:
# Index(['accl_x', 'accl_y', 'accl_z', 'gyr_x', 'gyr_y', 'gyr_z', 'label',
#        'category', 'participant', 'set'],
#       dtype='object')

# %%
merged_data.columns
# Out:
# Index(['accl_x', 'accl_y', 'accl_z', 'gyr_x', 'gyr_y', 'gyr_z', 'label',
#        'category', 'participant', 'set'],
#       dtype='object')

# %%
merged_data
# Out:
#                          accl_x  accl_y  accl_z   gyr_x  gyr_y  gyr_z label  \
# epoch (ms)
# 2019-01-11 15:08:04.950     NaN     NaN     NaN -10.671 -1.524  5.976     B
# 2019-01-11 15:08:04.990     NaN     NaN     NaN  -8.720 -2.073  3.171     B
# 2019-01-11 15:08:05.030     NaN     NaN     NaN   0.488 -3.537 -4.146     B
# 2019-01-11 15:08:05.070     NaN     NaN     NaN   0.244 -5.854  3.537     B
# 2019-01-11 15:08:05.110     NaN     NaN     NaN  -0.915  0.061 -2.805     B
# ...                         ...     ...     ...     ...    ...    ...   ...
# 2019-01-20 17:35:13.382  -0.060  -1.021  -0.058     NaN    NaN    NaN   NaN
# 2019-01-20 17:35:13.462  -0.035  -1.037  -0.026     NaN    NaN    NaN   NaN
# 2019-01-20 17:35:13.542  -0.045  -1.029  -0.033     NaN    NaN    NaN   NaN
# 2019-01-20 17:35:13.622  -0.039  -1.027  -0.039     NaN    NaN    NaN   NaN
# 2019-01-20 17:35:13.702  -0.049  -1.031  -0.049     NaN    NaN    NaN   NaN
#
#                         category participant   set
# epoch (ms)
# 2019-01-11 15:08:04.950    bench       heavy  80.0
# 2019-01-11 15:08:04.990    bench       heavy  80.0
# 2019-01-11 15:08:05.030    bench       heavy  80.0
# 2019-01-11 15:08:05.070    bench       heavy  80.0
# 2019-01-11 15:08:05.110    bench       heavy  80.0
# ...                          ...         ...   ...
# 2019-01-20 17:35:13.382      NaN         NaN   NaN
# 2019-01-20 17:35:13.462      NaN         NaN   NaN
# 2019-01-20 17:35:13.542      NaN         NaN   NaN
# 2019-01-20 17:35:13.622      NaN         NaN   NaN
# 2019-01-20 17:35:13.702      NaN         NaN   NaN
#
# [69677 rows x 10 columns]

# %%
sampling = {"accl_x": "mean", "accl_y":"mean", "accl_z":"mean", "gyr_x":"mean", "gyr_y":"mean", "gyr_z":"mean", "label":"mean", "category":"last", "participant":"last", "set":"last",}

# %%
merged_data[:1000].resample(rule="200ms").apply(sampling)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/groupby/generic.py in array_func(values)
#     340                 result = self.grouper._cython_operation(
# --> 341                     "aggregate", values, how, axis=data.ndim - 1, min_count=min_count
#     342                 )
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#    1015             ngroups=ngroups,
# -> 1016             **kwargs,
#    1017         )
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/groupby/ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     676             mask=None,
# --> 677             **kwargs,
#     678         )
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, **kwargs)
#     507                 mask=mask,
# --> 508                 **kwargs,
#     509             )
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _call_cython_op(self, values, min_count, ngroups, comp_ids, mask, **kwargs)
#     562         out_shape = self._get_output_shape(ngroups, values)
# --> 563         func, values = self.get_cython_func_and_vals(values, is_numeric)
#     564         out_dtype = self.get_out_dtype(values.dtype)
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/groupby/ops.py in get_cython_func_and_vals(self, values, is_numeric)
#     204
# --> 205         func = self._get_cython_function(kind, how, values.dtype, is_numeric)
#     206
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _get_cython_function(cls, kind, how, dtype, is_numeric)
#     170                 raise NotImplementedError(
# --> 171                     f"function is not implemented for this dtype: "
#     172                     f"[how->{how},dtype->{dtype_str}]"
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1602         try:
# -> 1603             x = float(x)
#    1604         except (TypeError, ValueError):
#
# ValueError: could not convert string to float: 'BB'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1606             try:
# -> 1607                 x = complex(x)
#    1608             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# ~/Desktop/works/ml_fitness_tracker/src/data/dataset.py in <module>
# ----> <a href='file:///home/kyoto_123/Desktop/works/ml_fitness_tracker/src/data/dataset.py?line=147'>148</a> merged_data[:1000].resample(rule="200ms").apply(sampling)
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/resample.py in aggregate(self, func, *args, **kwargs)
#     333     def aggregate(self, func, *args, **kwargs):
#     334
# --> 335         result = ResamplerWindowApply(self, func, args=args, kwargs=kwargs).agg()
#     336         if result is None:
#     337             how = func
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/apply.py in agg(self)
#     159
#     160         if is_dict_like(arg):
# --> 161             return self.agg_dict_like()
#     162         elif is_list_like(arg):
#     163             # we require a list, but not a 'str'
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/apply.py in agg_dict_like(self)
#     434             # key used for column selection and output
#     435             results = {
# --> 436                 key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     437             }
#     438
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/apply.py in <dictcomp>(.0)
#     434             # key used for column selection and output
#     435             results = {
# --> 436                 key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     437             }
#     438
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     241
#     242         if isinstance(func, str):
# --> 243             return getattr(self, func)(*args, **kwargs)
#     244
#     245         elif isinstance(func, abc.Iterable):
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only)
#    1688             "mean",
#    1689             alt=lambda x: Series(x).mean(numeric_only=numeric_only),
# -> 1690             numeric_only=numeric_only,
#    1691         )
#    1692         return result.__finalize__(self.obj, method="groupby")
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     350             return result
#     351
# --> 352         result = array_func(objvals)
#     353
#     354         ser = self.obj._constructor(
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/groupby/generic.py in array_func(values)
#     346                 # try to python agg
#     347                 # TODO: shouldn't min_count matter?
# --> 348                 result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#     349
#     350             return result
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, values, ndim, alt)
#    1396         #  should always be preserved by the implemented aggregations
#    1397         # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1398         res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1399
#    1400         if isinstance(values, Categorical):
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#    1058
#    1059         else:
# -> 1060             result = self._aggregate_series_fast(obj, func)
#    1061
#    1062         npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _aggregate_series_fast(self, obj, func)
#    1281         #  - len(self.bins) > 0
#    1282         sbg = libreduction.SeriesBinGrouper(obj, func, self.bins)
# -> 1283         result, _ = sbg.get_result()
#    1284         return result
#    1285
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesBinGrouper.get_result()
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/_libs/reduction.pyx in pandas._libs.reduction._BaseGrouper._apply_to_group()
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    1687         result = self._cython_agg_general(
#    1688             "mean",
# -> 1689             alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    1690             numeric_only=numeric_only,
#    1691         )
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10749         )
#   10750         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10751             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10752
#   10753         setattr(cls, "mean", mean)
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10368     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
#   10369         return self._stat_function(
# > 10370             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10371         )
#   10372
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10353             )
#   10354         return self._reduce(
# > 10355             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10356         )
#   10357
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4390                 )
#    4391             with np.errstate(all="ignore"):
# -> 4392                 return op(delegate, skipna=skipna, **kwds)
#    4393
#    4394     def _reindex_indexer(
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      92             try:
#      93                 with np.errstate(invalid="ignore"):
# ---> 94                     return f(*args, **kwargs)
#      95             except ValueError as e:
#      96                 # we want to transform an object array
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     154                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     155             else:
# --> 156                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157
#     158             return result
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     409             mask = isna(values)
#     410
# --> 411         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     412
#     413         if datetimelike:
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     664
#     665     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 666     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     667
#     668     if axis is not None and getattr(the_sum, "ndim", False):
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1608             except ValueError as err:
#    1609                 # e.g. "foo"
# -> 1610                 raise TypeError(f"Could not convert {x} to numeric") from err
#    1611     return x
#    1612
#
# TypeError: Could not convert BB to numeric

# %%
sampling = {"accl_x": "mean", "accl_y":"mean", "accl_z":"mean", "gyr_x":"mean", "gyr_y":"mean", "gyr_z":"mean", "label":"last", "category":"last", "participant":"last", "set":"last",}

# %%
merged_data[:1000].resample(rule="200ms").apply(sampling)
# Out:
#                            accl_x    accl_y    accl_z    gyr_x    gyr_y  \
# epoch (ms)
# 2019-01-11 15:08:04.800       NaN       NaN       NaN -9.69550  -1.7985
# 2019-01-11 15:08:05.000       NaN       NaN       NaN -2.01220  -0.4270
# 2019-01-11 15:08:05.200  0.013500  0.977000 -0.071000 -1.89040   2.4392
# 2019-01-11 15:08:05.400 -0.001500  0.970500 -0.079500 -1.68260  -0.8904
# 2019-01-11 15:08:05.600  0.001333  0.971667 -0.064333  2.56080  -0.2560
# ...                           ...       ...       ...      ...      ...
# 2019-01-11 15:10:21.600 -0.174000  1.092667 -0.153333 -4.96360 -16.4026
# 2019-01-11 15:10:21.800 -0.219500  1.402500 -0.109000 -7.52440  18.6706
# 2019-01-11 15:10:22.000 -0.192000  0.871667 -0.155667  2.60980   8.7070
# 2019-01-11 15:10:22.200 -0.227000  0.891000 -0.170000  5.39020   4.0000
# 2019-01-11 15:10:22.400 -0.225500  0.919500 -0.205500  6.34125   0.5795
#
#                            gyr_z label category participant   set
# epoch (ms)
# 2019-01-11 15:08:04.800   4.5735     B    bench       heavy  80.0
# 2019-01-11 15:08:05.000  -1.6218     B    bench       heavy  80.0
# 2019-01-11 15:08:05.200   0.9388     B    bench       heavy  80.0
# 2019-01-11 15:08:05.400   2.1708     B    bench       heavy  80.0
# 2019-01-11 15:08:05.600  -1.4146     B    bench       heavy  80.0
# ...                          ...   ...      ...         ...   ...
# 2019-01-11 15:10:21.600  21.9026     A    bench       heavy  47.0
# 2019-01-11 15:10:21.800 -22.6828     A    bench       heavy  47.0
# 2019-01-11 15:10:22.000 -14.8658     A    bench       heavy  47.0
# 2019-01-11 15:10:22.200  -0.3780     A    bench       heavy  47.0
# 2019-01-11 15:10:22.400   9.9085     A    bench       heavy  47.0
#
# [689 rows x 10 columns]
